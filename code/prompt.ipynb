# %% [markdown]
# #### Prompt Engineering Langchain

# %%
import os
from constants import openai_key

# %%
import os
os.environ["api_key"]=openai_key

# %%
from langchain.prompts import PromptTemplate

demo_template=''' Iwant you act as a acting financial advisor for people.
in an easy way, explain the basics of {financial_concept}.'''

prompt=PromptTemplate(
    input_variables=["financial_concept"],
    template=demo_template
    

)

prompt.format(financial_concept="income tax")
# Out:
# ' Iwant you act as a acting financial advisor for people.\nin an easy way, explain the basics of income tax.'

# %%
from langchain.llms import OpenAI
from langchain.chains import LLMChain

llm = OpenAI(temperature=0.7, openai_api_key=openai_key)
chain1=LLMChain(llm=llm, prompt=prompt)
# Out:
# C:\Users\LAP-STORE\AppData\Local\Temp\ipykernel_5104\3652579625.py:4: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(temperature=0.7, openai_api_key=openai_key)
# C:\Users\LAP-STORE\AppData\Local\Temp\ipykernel_5104\3652579625.py:5: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain1=LLMChain(llm=llm, prompt=prompt)

# %%
chain1.run("income tax")
# Out:
# C:\Users\LAP-STORE\AppData\Local\Temp\ipykernel_5104\403663222.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain1.run("income tax")
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 chain1.run("income tax")
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\_api\deprecation.py:190, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     warned = True
#     189     emit_warning()
# --> 190 return wrapped(*args, **kwargs)
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
# ...

# %%
chain1.run("GDP")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 chain1.run("GDP")
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\_api\deprecation.py:190, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     warned = True
#     189     emit_warning()
# --> 190 return wrapped(*args, **kwargs)
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
#     631 if kwargs and not args:
# ...

# %%
### language Translation
from langchain.prompts import PromptTemplate

template=''' In an easy way translate the following sentence '{sentence}' into {target_language}'''
language_prompt=PromptTemplate(
    input_variables=["sentence","target_language"],
    template=template,
)
language_prompt.format(sentence="How are you",target_language="french")
# Out:
# " In an easy way translate the following sentence 'How are you' into french"

# %%
chain2=LLMChain(llm=llm, prompt=language_prompt)

chain2({"sentence":"Hallo How are you", "target_language":"french"})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 chain2=LLMChain(llm=llm, prompt=language_prompt)
# ----> 3 chain2({"sentence":"Hallo How are you", "target_language":"french"})
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\_api\deprecation.py:190, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     warned = True
#     189     emit_warning()
# --> 190 return wrapped(*args, **kwargs)
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain\chains\base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     378 """Execute the chain.
#     379
#     380 Args:
#    (...)
#     401         `Chain.output_keys`.
#     402 """
#     403 config = {
# ...

# %%
from langchain import PromptTemplate, FewShotPromptTemplate

#frist creat the list of few shot examples
examples=[
    {"word": "happy", "antonym": "sad"},
    {"word": "tall", "antonym": "short"},
]

# next we specify the template to formate the examples we have provided
# we usr the "promptTemplate" class for this
example_formatter_template='''word:{word}
Antonym: {antonym}'''

example_prompt=PromptTemplate(
    input_variables=["word","antonym"],
    template=example_formatter_template,
)

# %%
# finally, we creat the fewshotpromptTemplate
few_shot_prompt=FewShotPromptTemplate(
    # these are examples we want to insert into the prompt
    examples=examples,
    # this is how we want to format the examples when we insert them into the prompt
    example_prompt=example_prompt,
    # the prefix is some text that goes before the examples in the prompt.
    # usually this consists of instructions
    prefix="Give the antonym of every input\n",

    # the suffix is some text that goes after the examples in the prompt.
    # usually this is where the user input will go
    suffix="word : {input}\nAntonym: ",
    # the input variables are the variables are overall prompt expects.
    input_variables=["input"],
    # the example_separatot is the string we will use to join the prefix, examples
    example_separator="\n",

)

# %%
print(few_shot_prompt.format(input="big"))
# Out:
# Give the antonym of every input
#
# word:happy
# Antonym:sad
# word:tall
# Antonym:short
# word : big
# Antonym:

# %%
chain=LLMChain(llm=llm,prompt=few_shot_prompt)
chain.run("big")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 chain=LLMChain(llm=llm,prompt=few_shot_prompt)
# ----> 2 chain.run("big")
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\_api\deprecation.py:190, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     188     warned = True
#     189     emit_warning()
# --> 190 return wrapped(*args, **kwargs)
#
# File c:\Users\LAP-STORE\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
# ...
